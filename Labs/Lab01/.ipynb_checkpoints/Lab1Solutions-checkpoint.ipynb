# %% [markdown]
# # AST 337 In-Class Lab #1
# ### Wednesday, September 5, 2018
#
# ## Names:
# ____

# %% [markdown]
# In this lab, you'll learn to read in and manipulate tabular data with a python package called _pandas_ and plot that data with the plotting module _matplotlib.pyplot_.
#
# On the science end, you will compare H-R diagrams for two different open star clusters, a globular cluster, and a  population of field (non-cluster) stars.

# %%
# First, import (load) packages we'll need to use, and give them shortcut names for easy use later on: 

import pandas as pd # Pandas is a software library for working with data tables
import numpy as np # Numerical Python (numpy) allows us to work with arrays and matrices
import matplotlib.pyplot as plt # matplotlib is Python's main plotting library

# The following is necessary to show the plots we make inside the notebook (i.e., inline = not separate windows)
# %matplotlib inline

# %% [markdown]
# In the current directory, there are files of astronomical measurements for various clusters of stars. We want to be able to manipulate and use datafiles within python, and so we'll need to read in the data. Here, we will use the pandas function *read_csv*. A basic example is given below:

# %%
pleiades = pd.read_csv('pleiades.csv')

# %% [markdown]
# "pleiades" is now a pandas dataframe object, which is essentially a form of python table. To see what's stored in pleiades, execute the cell below. Anywhere you see ..., that means that there are a number of additional columns or rows that have been hidden.

# %%
pleiades
# Out:
#       Full           _RAJ2000           _DEJ2000                DANCe   Nep  \
# 0      NaN  h:m:s"""h:m:s""""  d:m:s"""d:m:s""""                  NaN   NaN
# 1      1.0       03 49 58.055       +23 50 55.36  J034958.05+235055.0   2.0
# 2      2.0       03 46 12.686       +23 07 42.80  J034612.70+230742.3   2.0
# 3      3.0       03 36 10.758       +26 15 52.35  J033610.76+261552.1   2.0
# 4      4.0       03 44 58.925       +22 01 56.79  J034458.93+220156.4   5.0
# 5      5.0       03 53 01.298       +23 03 25.19  J035301.32+230324.7   4.0
# 6      6.0       03 39 09.121       +24 22 04.04  J033909.14+242203.7   5.0
# 7      7.0       03 51 06.339       +25 35 40.82  J035106.35+253540.5  13.0
# 8      8.0       03 44 39.665       +22 06 47.88  J034439.67+220647.5   4.0
# 9      9.0       03 44 20.515       +24 46 22.26  J034420.52+244621.8   9.0
# 10    10.0       03 45 15.355       +25 17 22.08  J034515.36+251721.7  14.0
# 11    11.0       03 41 19.346       +23 51 41.98  J034119.35+235141.7  22.0
# 12    12.0       03 52 17.630       +24 27 18.59  J035217.64+242718.4  20.0
# 13    13.0       03 43 53.867       +25 28 30.28  J034353.87+252830.3  23.0
# 14    14.0       03 45 45.126       +25 35 44.89  J034545.14+253544.6  18.0
# 15    15.0       03 45 05.310       +25 29 11.19  J034505.31+252911.1  37.0
# 16    16.0       03 53 50.263       +25 57 52.68  J035350.27+255752.4  13.0
# 17    17.0       03 29 25.401       +25 39 08.32  J032925.41+253908.1   2.0
# 18    18.0       03 47 23.971       +23 54 52.22  J034723.98+235452.0   4.0
# 19    19.0       03 47 33.676       +24 41 03.17  J034733.69+244102.8  30.0
# 20    20.0       03 46 38.889       +24 31 13.16  J034638.90+243112.8  41.0
# 21    21.0       03 48 13.571       +24 19 06.03  J034813.57+241906.0   4.0
# 22    22.0       03 49 56.602       +24 20 56.49  J034956.60+242056.3   2.0
# 23    23.0       03 50 12.404       +24 31 58.62  J035012.41+243158.3  45.0
# 24    24.0       03 49 16.793       +24 23 46.10  J034916.79+242346.0   2.0
# 26   10.319     NaN   9.312   8.935   8.816  0.9997   5250  9.13E-01
# 27   10.908     NaN   9.835   9.389   9.266  0.9999   5000  5.22E-01
# 28   10.846     NaN   9.801   9.528   9.398  0.9999   5250  5.55E-01
# 29    9.859     NaN   9.041   8.817   8.736  0.9999   6000  1.38E+00
# ..      ...     ...     ...     ...     ...     ...    ...       ...
# 756     NaN  17.928  17.006  16.284  15.768  0.9994   2300  3.57E-04
# 757  17.503  15.323   14.67  14.169  13.787  0.9996   2900  3.09E-03
# 758  22.172  18.573  17.436  16.664  16.051  1.0000   2200  2.45E-04
# 759  15.979  14.134  13.546  13.006  12.694  0.9998   3200  9.31E-03
# 760   15.84  14.093  13.516  12.934  12.675  0.9994   3200  9.82E-03
# 761  16.819  14.841  14.239  13.677  13.324  0.9995   3000  5.01E-03
# 762     NaN  17.679  16.599  15.993  15.481  0.9998   2300  4.76E-04
# 763   9.918     NaN   9.003   8.778    8.66  1.0000   5750  1.31E+00
# 764  16.014  14.156  13.564  13.007  12.716  0.9997   3100  9.24E-03
# 765   16.83  14.666  14.045  13.498  13.144  0.9994   2900  5.70E-03
# 766  15.846  13.965  13.425  12.889  12.528  0.9998   3200  1.07E-02
# 767  17.878  15.586  14.902  14.337  13.979  0.9997   2800  2.55E-03
# 768  17.556  15.369  14.707  14.187  13.827  0.9995   2900  2.99E-03
# 769     NaN     NaN  10.132    9.71   9.609  0.9995   5000  3.96E-01
# 770  18.024  15.751  15.096  14.566  14.146  0.9994   2900  2.09E-03
# 771  15.575  13.779  13.199  12.666   12.35  0.9994   3200  1.31E-02
# 772  16.182  14.243  13.647  13.132  12.818  0.9996   3100  8.39E-03
# 773  15.573  13.774  13.191  12.682  12.367  0.9999   3200  1.29E-02
# 774  17.764  15.515  14.868  14.337  13.976  0.9999   2900  2.52E-03
# 775  16.957  14.963  14.358  13.825  13.479  0.9996   3000  4.38E-03
# 776  17.548  15.346   14.71  14.173  13.814  0.9997   2900  3.03E-03
# 777  16.977  14.951  14.332  13.794  13.454  0.9993   3000  4.44E-03
# 778  22.258  18.908  17.618  16.832  16.114  1.0000   2200  2.13E-04
# 779  16.251  14.375  13.775  13.251  12.913  0.9995   3100  7.55E-03
# 780  22.335  18.971   17.81  17.035  16.342  0.9997   1900  1.81E-04
# 781     NaN     NaN   7.485   7.449   7.388  1.0000   7500  7.64E+00
# 782   9.898     NaN   9.152   8.904   8.848  0.9999   6000  1.26E+00
# 783     NaN     NaN   7.058   7.009   7.008  1.0000   8250  1.45E+01
# 784     NaN     NaN   7.024   7.023   6.994  0.9994   9000  2.26E+01
# 785   8.339     NaN   7.714   7.574    7.57  1.0000   6000  4.13E+00
#
# [786 rows x 22 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip: Viewing Data Files</b> <p>
#
# If you want to view a raw data file directly, you can view the CSV (comma-separated value) file in the Jupyter environment. Try going to the home directory (which lists all of the .ipynb files and .csv files) and click the checkbox to the left of "Pleiades.csv". Then click the Edit button at the top of the screen. A new tab should open in your browser that looks like the following:
#
# <img src="data.png" alt="Alt text that describes the graphic" title="Title text" />
#
# </div>

# %% [markdown]
# Perhaps more useful are the pandas .columns and .dtypes methods. Execute the cells below and then edit the descriptions of what each does in the cell below (double click on this text to get into the markdown cell, where you can type regular text)
#
# **(1)** The .columns method does.... **[your answer]**
#
# **(2)** The .dtypes method does.... **[your answer]**

# %%
## Solutions:

# 1. Column method provides header labels for each column in the dataset, including coordinates, magnitudes, etc.

# 2. Datatypes tells what format the column data are in - object or float format in this case - pandas is not quite 
#    sure what the entries are supposed to be in the columns it declared as "object", so it defines them as a 
#    generic non-numeric series of values.

# %%
pleiades.columns

# %%
pleiades.dtypes
# Out:
# Full        float64
# _RAJ2000     object
# _DEJ2000     object
# DANCe        object
# Nep         float64
# RAJ2000      object
# DEJ2000      object
# pmRA         object
# pmDE         object
# chi2r       float64
# Epoch        object
# umag         object
# gmag         object
# rmag         object
# imag         object
# Ymag         object
# Jmag         object
# Hmag         object
# Kmag         object
# Pmb         float64
# Teff         object
# Lbol         object
# dtype: object

# %% [markdown]
# The two columns that we care about for this lab are the Temperature (Teff) and the Luminosity (Lbol). The units for these two columns are Kelvin and Solar luminosities, respectively. As you will label these later in your plots, I'll note here that there's a special trick for getting the sun symbol in a Markdown cell using the typesetting system LaTeX.
#
# Solar Luminosities = L$_{\odot}$
#
# Double click on this cell to see how I made the symbol above.
#
# Let's create a pandas series that we can manipulate from each of the columns of interest.

# %%
pleiades_L = pleiades["Lbol"]
pleiades_T = pleiades["Teff"]

# %% [markdown]
# Note though from your .dtypes output above that both of these columns have dtype "object", which is not a data type that will allow us to manipulate them. For example, try executing the cell below, where we attempt to subtract the value 2 from each entry in the "pleiades_L" column. You should get an error...

# %%
pleiades_L = pleiades_L - 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     657             result = expressions.evaluate(op, str_rep, x, y,
# --> 658                                           raise_on_error=True, **eval_kwargs)
#     659         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     210         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 211                          **eval_kwargs)
#     212     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
#     121     if result is None:
# --> 122         result = _evaluate_standard(op, op_str, a, b, raise_on_error)
#     123
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#     681             with np.errstate(all='ignore'):
# --> 682                 return na_op(lvalues, rvalues)
#     683         except Exception:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     667                 mask = notnull(x)
# --> 668                 result[mask] = op(x[mask], y)
#     669             else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2235e1aee874> in <module>()
# ----> 1 pleiades_L = pleiades_L - 2
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(left, right, name, na_op)
#     719                 lvalues = lvalues.values
#     720
# --> 721         result = wrap_results(safe_na_op(lvalues, rvalues))
#     722         return construct_result(
#     723             left,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in safe_na_op(lvalues, rvalues)
#     690                 if is_object_dtype(lvalues):
#     691                     return libalgos.arrmap_object(lvalues,
# --> 692                                                   lambda x: op(x, rvalues))
#     693             raise
#     694
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x)
#     690                 if is_object_dtype(lvalues):
#     691                     return libalgos.arrmap_object(lvalues,
# --> 692                                                   lambda x: op(x, rvalues))
#     693             raise
#     694
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip: Reading Python Errors</b> <p>
#
# Error messages in Python are most easily read starting from the bottom. The bottom of this error states:<p>
#
# `TypeError: unsupported operand type(s) for -: 'str' and 'int'`<p>
#
# This is telling us that the object `pleiades_L` has a string format (str) while `2` is an integer format (int), and python cannot do arithmetic between strings and integers. (Like asking it to calculate 3.14 + 'hello' would similarly result in a TypeError between a float and a string.)<p>
#
# Our error message then traces back the error at each step, originating with our main issue at the top, telling us where we went wrong: <p>
#
# `----> 1 pleiades_L = pleiades_L - 2` <p>
#
# -> Whenever you encounter an error, always start reading from the bottom and then go up to the top where it pinpointed the original issue!
#
# </div>

# %% [markdown]
# Therefore, we want to convert the type of these pandas series to be numeric, which we do with pandas.to_numeric, as below:

# %%
pleiades_L_new = pd.to_numeric(pleiades_L, errors='coerce')
pleiades_T_new = pd.to_numeric(pleiades_T, errors='coerce')

# With "coerce", we are telling the to_numeric function to change any invalid entries to NaNs.

# %% [markdown]
# Now let's print the first ten elements of each array to verify that nothing weird happened during this conversion.

# %%
pleiades_L[0:10], pleiades_L_new[0:10], pleiades_T[0:10], pleiades_T_new[0:10]
# Out:
# (0        Lsun
#  1    1.83E+01
#  2    5.26E+00
#  3    1.27E+00
#  4    2.02E+00
#  5    1.28E+00
#  6    1.72E+00
#  7    3.06E+00
#  8    6.91E-01
#  9    7.45E-01
#  Name: Lbol, dtype: object, 0       NaN
#  1    18.300
#  2     5.260
#  3     1.270
#  4     2.020
#  5     1.280
#  6     1.720
#  7     3.060
#  8     0.691
#  9     0.745
#  Name: Lbol, dtype: float64, 0       K
#  1    7500
#  2    6000
#  3    5750
#  4    5750
#  5    5750
#  6    5750
#  7    6250
#  8    5250
#  9    5000
#  Name: Teff, dtype: object, 0       NaN
#  1    7500.0
#  2    6000.0
#  3    5750.0
#  4    5750.0
#  5    5750.0
#  6    5750.0
#  7    6250.0
#  8    5250.0
#  9    5000.0
#  Name: Teff, dtype: float64)

# %% [markdown]
# Now let's plot these two quantities against one another. There are many ways to plot in pyplot, but below is a simple version that often works most consistently and intuitively:

# %%
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(pleiades_T_new, pleiades_L_new)

# %% [markdown]
# Yikes, that's ugly, right? That's because the default plot symbol is a line connecting all the points. In this case what we really want is a so-called scatterplot, which we can do easily by specifying the plotting marker right after the y variable, as below. Below I use 'o', which stands for the circle symbol. For the full list of matplotlib symbols, see [this link](https://matplotlib.org/api/markers_api.html).

# %%
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(pleiades_T_new, pleiades_L_new, 'o')

# %% [markdown]
# Note the default plotting color is blue, but you can change this easily by adding a color shorthand before the marker shorthand. Below I use 'g' for green, but here again, there are lots of options, as outlined at [this link](https://matplotlib.org/api/colors_api.html).
#
# There is also a very large list of named colors, available here: [Matplotlib Named Colors](https://matplotlib.org/examples/color/named_colors.html)

# %%
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(pleiades_T_new, pleiades_L_new, 'go')

# %% [markdown]
# Colors notwithstanding, this plot is still very ugly and should not look much like an H-R diagram to you. For one thing, H-R diagrams usually have log(Luminosity) on the y-axis. To change one of the axes to a log scale, do the following:

# %%
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(pleiades_T_new, pleiades_L_new, 'go')
ax.set_yscale('log')

# %% [markdown]
# OK that's much nicer, but should still look backwards to you, because we always draw H-R Diagrams with the Temperature axis running from high to low temperature. This is a pretty easy fix too -- note that we have simply set the X-axis limits from a large value to a small one.

# %%
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(pleiades_T_new, pleiades_L_new, 'go')
ax.set_yscale('log')
ax.set_xlim(11000,1000)
# Out:
# (11000, 1000)

# %% [markdown]
# OK! This is starting to look like a good H-R diagram, but without a plot title or axis labels, it's still not very good, so let's add those.

# %%
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(pleiades_T_new, pleiades_L_new, 'go')
ax.set_yscale('log')
ax.set_xlim(11000,1000)
plt.title('H-R Diagram for the Pleiades')
plt.xlabel('Temperature (in K)')
plt.ylabel('log[Luminosity (in L$_{\odot}$)]')

# %% [markdown]
# # Exercise 1
#
# Now it's time for you to do some exploring with the rest of the data. For each of the remaining four data files in the Lab 1 directory:
#
# 1) read in the data
#
# 2) find the columns for luminosity and temperature
#
# (note that some of the raw data has units of log(L) or log(T), which you'll have to "undo" to get the regular units of L and T. Refer to the Homework0 Exercise #1 if you can't remember how)
#
# 3) assign the relevant columns to pandas series and convert data types to numeric as necessary
#
# 4) make a plot of the data with appropriate axis labels, ranges, a plot title, etc.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Important Note:</b> You always want to ensure that your plots depict an accurate representation of the data - so be sure to discuss with your partner how best to adjust the axes limits, how to show the full range of values, and/or ways to make the data most legible and clear to see (point symbol, size, etc).
# </div>

# %%
## Add code here to read in the other three files in the Lab 1 directory, and give them descriptive variable names.

# %%
## Add code here to identify the column labels for luminosity and temperature. Be careful - columns may not have
## the same names, and be sure to check the units of the quantities.

# %%
## Convert to pandas series and data types, if necessary.

# %%
## Plot the data in this cell and the following cells for each sample:
## Hyades Plot

# %%
## Field Plot

# %%
## 47 Tuc Plot

# %%
##------------------------------##

# Solutions:
hyades = pd.read_csv('hyades.csv')
field = pd.read_csv('field_sample.csv')
globular = pd.read_csv('47_Tucanae.csv')

# %%
# Solutions:
# Hyades 
hyades_L = hyades["logLum"]
hyades_T = hyades["logTeff"]
hyades_L_new = 10**pd.to_numeric(hyades_L, errors='coerce')
hyades_T_new = 10**pd.to_numeric(hyades_T, errors='coerce')

# Field
field_L = field["Lstar_Lsun"]
field_T = field["Teff"]
field_L_new = pd.to_numeric(field_L, errors='coerce')
field_T_new = pd.to_numeric(field_T, errors='coerce')

# Globular
globular_L = globular["Lstar_Lsun"]
globular_T = globular["Teff"]
globular_L_new = pd.to_numeric(globular_L, errors='coerce')
globular_T_new = pd.to_numeric(globular_T, errors='coerce')

# %%
# Solutions:
# Hyades
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(hyades_T_new, hyades_L_new, 'ro')
ax.set_yscale('log')
ax.set_xlim(11000,1000)
plt.title('H-R Diagram for the Hyades')
plt.xlabel('Temperature (in K)')
plt.ylabel('log[Luminosity (in L$_{\odot}$)]')

# %%
# Solutions:
# Field
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(field_T_new, field_L_new, 'bo', ms=2)
ax.set_yscale('log')
ax.set_xlim(12000,500)
plt.title('H-R Diagram for a Field Population')
plt.xlabel('Temperature (in K)')
plt.ylabel('log[Luminosity (in L$_{\odot}$)]')

# %%
# Solutions:
# 47 Tuc
fig,ax = plt.subplots(figsize=(7,7))
ax.plot(globular_T_new, globular_L_new, 'mo')
ax.set_yscale('log')
ax.set_xlim(8000,2000)
plt.title('H-R Diagram for 47 Tuc')
plt.xlabel('Temperature (in K)')
plt.ylabel('log[Luminosity (in L$_{\odot}$)]')

# %% [markdown]
# # Exercise 2 (Multi-Panel Plots)
#
# The individual plots for each of these clusters are nice, but really we'd like to be able to compare them side-by-side. You can do this by making either a multi-panel plot, or an overlapping plot. A skeleton outline of how to do each is below. Please use this as a framework to make similar plots with our data.

# %%
#some fake data
data_x = np.arange(0,100)
data_y = 3*data_x
data_y2 = data_x**2
data_y3 = data_x + 20
data_y4 = np.sqrt(data_x)

# %%
# multipanel plot example
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2, 2, figsize=(10,10))
fig.suptitle('This is a title for my multipanel plot')
ax1.plot(data_x, data_y, 'go')
ax1.set_title('Figure 1 Title')
ax1.set_xlabel('x label')
ax1.set_ylabel('y label')
ax2.plot(data_x, data_y2, 'bo')
ax2.set_title('Figure 2 Title')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')
ax3.plot(data_x, data_y3, 'ro')
ax3.set_title('Figure 3 Title')
ax3.set_xlabel('x label')
ax3.set_ylabel('y label')
ax4.plot(data_x, data_y4, 'mo')
ax4.set_title('Figure 4 Title')
ax4.set_xlabel('x label')
ax4.set_ylabel('y label')

# %%
#overlay plot example
fig,ax = plt.subplots(figsize=(10,10))
plt.title('This is a title for my multipanel plot')
ax.plot(data_x, data_y, 'go', label='legend entry 1', alpha=0.5)
ax.plot(data_x, data_y2, 'bo', label='legend entry 2', alpha=0.5)
ax.plot(data_x, data_y3, 'ro', label='legend entry 2', alpha=0.5)
ax.plot(data_x, data_y4, 'mo', label='legend entry 2', alpha=0.5)
ax.set_title('Figure Title')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
plt.legend(numpoints=1)
#TRY EXECUTING WITH AND WITHOUT THE FOLLOWING LINE. HERE AND IN THE DATA YOU'LL BE PLOTTING, 
#A SUBJECTIVE DECISION MUST BE MADE ABOUT AXIS RANGES
ax.set_ylim(0,200)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Important Note:</b> Again, discuss in your group the best ways to make the data most legible and clear (point symbol, size, etc). Since we will also be plotting multi-panel plots, consider how (or if!) you should change the axes for each of the panels individually as well.
# </div>

# %%
## In this cell, create your own overlay plot showing the different populations. Hint: You may want to plot the 
## sample with the most data points first.

# %%
## In this cell, create a multi-panel plot for the different populations.

# %%
##------------------------------##

# Solutions:
fig,ax = plt.subplots(figsize=(10,10))

ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlim(15000,1000)

ax.plot(field_T_new, field_L_new, '.', color='lightskyblue', label='Field')
ax.plot(globular_T_new, globular_L_new, '.', color='magenta', alpha=0.5, label='47 Tuc')

ax.plot(hyades_T_new, hyades_L_new, 'r.', alpha=0.5, label='Hyades')
ax.plot(pleiades_T_new, pleiades_L_new, 'g.', alpha=0.5, label='Pleiades')

plt.legend(numpoints=1)

plt.title('Various Stellar Populations on the HR Diagram')
plt.xlabel('Temperature (in K)')
plt.ylabel('log[Luminosity (in L$_{\odot}$)]')

# %%
# Solutions:

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(2, 2, figsize=(14,14))
fig.suptitle('Various Stellar Populations on the HR Diagram')
ax1.plot(pleiades_T_new, pleiades_L_new, 'g.')
ax1.set_yscale('log')
ax1.set_xscale('log')
ax1.set_xlim(11000,1500)
ax1.set_title('Pleiades')
ax1.set_xlabel('Temperature (in K)')
ax1.set_ylabel('log[Luminosity (in L$_{\odot}$)]')

ax2.plot(field_T_new, field_L_new, 'b.')
ax2.set_yscale('log')
ax2.set_xscale('log')
ax2.set_xlim(12000,1000)
ax2.set_title('Field')
ax2.set_xlabel('Temperature (in K)')
ax2.set_ylabel('log[Luminosity (in L$_{\odot}$)]')

ax3.plot(hyades_T_new, hyades_L_new, 'r.')
ax3.set_yscale('log')
ax3.set_xscale('log')
ax3.set_xlim(10000,3200)
ax3.set_title('Hyades')
ax3.set_xlabel('Temperature (in K)')
ax3.set_ylabel('log[Luminosity (in L$_{\odot}$)]')

ax4.plot(globular_T_new, globular_L_new, 'm.')
ax4.set_yscale('log')
ax4.set_xscale('log')
ax4.set_xlim(8000,3000)
ax4.set_title('47 Tuc')
ax4.set_xlabel('Temperature (in K)')
ax4.set_ylabel('log[Luminosity (in L$_{\odot}$)]')

# %% [markdown]
# # Exercise 3 (Comprehension Questions)
#
# 1) Describe the differences between the H-R diagrams. Do this both qualitatively (note differences in their appearance) and quantitatively. You might find methods like .min and .max to be useful here.
#
# 2) Which of the four groups of stars has stars that are NOT on the main sequence, and which don't? Why, do you think?
#
# 3) Why do you think the low temperature (M-dwarf) end of the main sequence cuts off at such a different place in the four samples? Do you think this is a physical effect or an instrumental one and why?
#
# 4) Why do you think there are no white dwarfs in any of the samples besides the field sample?

# %%
## Your answers to each of the four questions here.

# %%
##------------------------------##

# Solutions (any elements of the following answers merit points):

# 1. Span different ranges of temperatures (field pop'n ranges most broadly from 1000 K to 12000 K, with Hyades 
#   ranging from 3500 K to 10000 K, 47 Tuc from 3000 to 7000 K, Pleaides from 1500 to 10000 K), and the main 
#   sequence length is different in each case with 47 Tuc having the most pronounced turn-off. The field pop'n is
#   the only population that shows both turn off stars and main sequence stars because the stars are all a mix of 
#   different ages, etc; the Hyades and Pleiades have almost no turn off stars (maybe a hint in the Hyades). 

# 2. The older populations (field and 47 Tuc) have stars that have evolved off of the main sequence, but the Hyades
#    and Pleiades are not yet old enough for significantly large populations of stars to have evolved.

# 3. Both effects, but instrumental limitation is the largest factor. Measuring the faintest stars in the most
#    distant clusters will be very challenging, hence the fact that there are very few cool dim stars in 47 Tuc 
#    (confusion limitations are also considerable for a globular). The field population which consists of 
#    stars very near to us enable the study of the dim cool stars. Survey depth also plays a role - the Pleiades 
#    survey is likely deeper than the Hyades one given its ability to reach low luminosities.

# 4. The Hyades and Pleiades do not have any white dwarfs in these studies, although they are old enough to have 
#    evolved them. It is possible that (a) there weren't that many high-mass stars to have evolved quickly enough or 
#   (b) the white dwarfs that *are* there are too faint to be detected in those surveys. 47 Tuc is more distant and 
#   old so the white dwarfs it has are likely too dim to be easily seen in this survey and easily confused with 
#   the crowded environment of the globular. Meanwhile, nearby field white dwarfs are much easier to detect, so show  
#   up readily in the field population.
